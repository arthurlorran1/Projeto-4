# %% [markdown]
# ### **Importando as bibliotecas**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Carregando os dados**

# %% [markdown]
# #### **M10**

# %%
index = 'C:/Users/47131502023.1/Desktop/repositories/Projeto-4/Data/precos-gasolina-etanol-10.csv'
etanol10 = pd.read_csv(index, sep=';')
etanol10
# Out:
#       Regiao - Sigla Estado - Sigla            Municipio  \
# 0                 NE             AL            ARAPIRACA
# 1                 NE             AL            ARAPIRACA
# 2                 NE             AL            ARAPIRACA
# 3                 NE             AL            ARAPIRACA
# 4                 NE             AL            ARAPIRACA
# ...              ...            ...                  ...
# 57470              S             RS               OSORIO
# 57471             SE             MG             OLIVEIRA
# 57472             SE             MG             OLIVEIRA
# 57473             NE             MA  SAO JOSE DE RIBAMAR
# 57474             NE             MA  SAO JOSE DE RIBAMAR
#
#                                                  Revenda      CNPJ da Revenda  \
# 0      COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 1      COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 2      COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 3                          AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
# 4                          AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
# ...                                                  ...                  ...
# 57470        POSTO ALDEIAO COMERCIO DE COMBUSTIVEIS LTDA   28.259.725/0002-07
# 57471                               AUTO POSTO AGLE LTDA   21.804.120/0011-93
# 57472                               AUTO POSTO AGLE LTDA   21.804.120/0011-93
# 57473  F DE A S CAMPOS COMBUSTIVEIS E LUBRIFICANTES LTDA   45.988.642/0001-89
# 57474  F DE A S CAMPOS COMBUSTIVEIS E LUBRIFICANTES LTDA   45.988.642/0001-89
#
#                           Nome da Rua Numero Rua Complemento  \
# 0              RODOVIA AL 220 - KM 06        S/N         NaN
# 1              RODOVIA AL 220 - KM 06        S/N         NaN
# 2              RODOVIA AL 220 - KM 06        S/N         NaN
# 3                   RUA SAO FRANCISCO        274         NaN
# 4                   RUA SAO FRANCISCO        274         NaN
# ...                               ...        ...         ...
# 57470            AVENIDA JORGE DARIVA       1536         NaN
# 57471            RUA AMINTAS DE SOUZA        147         NaN
# 57472            RUA AMINTAS DE SOUZA        147         NaN
# 57473  AVENIDA MASCARENHAS  DE MORAIS        444   QUADRA125
# 57474  AVENIDA MASCARENHAS  DE MORAIS        444   QUADRA125
#
#                     Bairro        Cep             Produto Data da Coleta  \
# 0                 PLANALTO  57308-000            GASOLINA     02/10/2023
# 1                 PLANALTO  57308-000  GASOLINA ADITIVADA     02/10/2023
# 2                 PLANALTO  57308-000              ETANOL     02/10/2023
# 3                   CENTRO  57300-080            GASOLINA     02/10/2023
# 4                   CENTRO  57300-080              ETANOL     02/10/2023
# ...                    ...        ...                 ...            ...
# 57470               CENTRO  95520-000              ETANOL     31/10/2023
# 57471               CENTRO  35540-000            GASOLINA     31/10/2023
# 57472               CENTRO  35540-000              ETANOL     31/10/2023
# 57473  VILA SARNEY FILHO I  65110-000            GASOLINA     31/10/2023
# 57474  VILA SARNEY FILHO I  65110-000              ETANOL     31/10/2023
#
#       Valor de Venda  Valor de Compra Unidade de Medida Bandeira
# 0               6,08              NaN        R$ / litro    VIBRA
# 1               6,08              NaN        R$ / litro    VIBRA
# 2               4,78              NaN        R$ / litro    VIBRA
# 3               5,79              NaN        R$ / litro    VIBRA
# 4               4,29              NaN        R$ / litro    VIBRA
# ...              ...              ...               ...      ...
# 57470           3,99              NaN        R$ / litro   RODOIL
# 57471           5,39              NaN        R$ / litro   BRANCA
# 57472           3,47              NaN        R$ / litro   BRANCA
# 57473           5,28              NaN        R$ / litro    VIBRA
# 57474           3,99              NaN        R$ / litro    VIBRA
#
# [57475 rows x 16 columns]

# %% [markdown]
# #### **M11**

# %%
index = 'C:/Users/47131502023.1/Desktop/repositories/Projeto-4/Data/precos-gasolina-etanol-11.csv'
etanol11 = pd.read_csv(index, sep=';')
etanol11
# Out:
#       Regiao - Sigla Estado - Sigla            Municipio  \
# 0                 NE             AL  PALMEIRA DOS INDIOS
# 1                 NE             AL  PALMEIRA DOS INDIOS
# 2                 NE             AL  PALMEIRA DOS INDIOS
# 3                 NE             AL  PALMEIRA DOS INDIOS
# 4                 NE             AL  PALMEIRA DOS INDIOS
# ...              ...            ...                  ...
# 52538             SE             SP              BIRIGUI
# 52539             SE             MG                  UBA
# 52540             SE             MG                  UBA
# 52541             SE             SP              BIRIGUI
# 52542             SE             SP              BIRIGUI
#
#                                     Revenda      CNPJ da Revenda  \
# 0             SEVERINO S. LOPES & CIA. LTDA   05.331.412/0002-09
# 1             SEVERINO S. LOPES & CIA. LTDA   05.331.412/0002-09
# 2             SEVERINO S. LOPES & CIA. LTDA   05.331.412/0002-09
# 3               A. B. LESSA NETO & CIA LTDA   05.562.589/0001-35
# 4               A. B. LESSA NETO & CIA LTDA   05.562.589/0001-35
# ...                                     ...                  ...
# 52538             POSTO UNI MIRAGAIA II LTD   48.886.073/0001-59
# 52539                   POSTO UIRAPURU LTDA   17.759.721/0004-25
# 52540                   POSTO UIRAPURU LTDA   17.759.721/0004-25
# 52541  AUTO POSTO BENEDETTI DE BIRIGUI LTDA   50.610.749/0001-29
# 52542  AUTO POSTO BENEDETTI DE BIRIGUI LTDA   50.610.749/0001-29
#
#                        Nome da Rua Numero Rua  \
# 0             AVENIDA MUNIZ FALCÃO       1640
# 1             AVENIDA MUNIZ FALCÃO       1640
# 2             AVENIDA MUNIZ FALCÃO       1640
# 3          AVENIDA VIEIRA DE BRITO       1888
# 4          AVENIDA VIEIRA DE BRITO       1888
# ...                            ...        ...
# 52538  AVENIDA   EUCLIDES MIRAGAIA       2704
# 52539          RUA ANTENOR MACHADO        268
# 52540          RUA ANTENOR MACHADO        268
# 52541    AVENIDA EUCLIDES MIRAGAIA       1678
# 52542    AVENIDA EUCLIDES MIRAGAIA       1678
#
#                                 Complemento             Bairro        Cep  \
# 0      LOTES 08 E 09, LOT. GASTÃO LEÃO REGO    JOSÉ MAIA COSTA  57605-260
# 1      LOTES 08 E 09, LOT. GASTÃO LEÃO REGO    JOSÉ MAIA COSTA  57605-260
# 2      LOTES 08 E 09, LOT. GASTÃO LEÃO REGO    JOSÉ MAIA COSTA  57605-260
# 3                                       NaN         VILA MARIA  57607-570
# 4                                       NaN         VILA MARIA  57607-570
# ...                                     ...                ...        ...
# 52538                                   NaN  VILA ISABEL MARIN  16200-130
# 52539                                   NaN             CENTRO  36500-012
# 52540                                   NaN             CENTRO  36500-012
# 52541                                   NaN        VILA PONTES  16200-130
# 52542                                   NaN        VILA PONTES  16200-130
#
#                   Produto Data da Coleta Valor de Venda  Valor de Compra  \
# 0                GASOLINA     01/11/2023            6,3              NaN
# 1      GASOLINA ADITIVADA     01/11/2023            6,3              NaN
# 2                  ETANOL     01/11/2023           4,88              NaN
# 3                GASOLINA     01/11/2023           6,19              NaN
# 4      GASOLINA ADITIVADA     01/11/2023           6,29              NaN
# ...                   ...            ...            ...              ...
# 52538  GASOLINA ADITIVADA     30/11/2023           5,99              NaN
# 52539            GASOLINA     30/11/2023           5,39              NaN
# 52540  GASOLINA ADITIVADA     30/11/2023           5,67              NaN
# 52541            GASOLINA     30/11/2023           4,87              NaN
# 52542              ETANOL     30/11/2023           2,99              NaN
#
#       Unidade de Medida  Bandeira
# 0            R$ / litro     VIBRA
# 1            R$ / litro     VIBRA
# 2            R$ / litro     VIBRA
# 3            R$ / litro     VIBRA
# 4            R$ / litro     VIBRA
# ...                 ...       ...
# 52538        R$ / litro  IPIRANGA
# 52539        R$ / litro    RAIZEN
# 52540        R$ / litro    RAIZEN
# 52541        R$ / litro    BRANCA
# 52542        R$ / litro    BRANCA
#
# [52543 rows x 16 columns]

# %% [markdown]
# ### **A análise deve responder às seguintes perguntas:**
#
# A análise deve responder às seguintes perguntas:
#
#     1. Como se comportaram o preço dos combustíveis durante os dois meses citados? Os valores do
#     etanol e da gasolina tiveram uma tendência de queda ou diminuição?
#     2. Qual o preço médio da gasolina e do etanol nesses dois meses?
#     3. Quais os 5 estados com o preço médio da gasolina e do etanol mais caros?
#     4. Qual o preço médio da gasolina e do etanol por estado?
#     5. Qual o município que possui o menor preço para a gasolina e para o etanol?
#     6. Qual o município que possui o maior preço para a gasolina e para o etanol?
#     7. Qual a região que possui o maior valor médio da gasolina?
#     8. Qual a região que possui o menor valor médio do etanol?
#     9. Há alguma correlação entre o valor do combustível (gasolina e etanol) e a região onde ele é vendido?
#     10.  Há alguma correlação entre o valor do combustível (gasolina e etanol) e a bandeira que vende ele?
#     Além disso, vocês deverão pensar em mais três perguntas que deverão ser respondidas por scripts.
