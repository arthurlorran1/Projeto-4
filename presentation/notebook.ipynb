# %% [markdown]
# ### **Importando as bibliotecas**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Carregando os dados**

# %% [markdown]
# #### **Novembro**

# %%
index = 'C:/Users/47131502023.1/Desktop/repositories/Projeto-4/Data/precos-gasolina-etanol-11.csv'
etanol11 = pd.read_csv(index, sep=';')
etanol11
# Out:
#       Regiao - Sigla Estado - Sigla            Municipio  \
# 0                 NE             AL  PALMEIRA DOS INDIOS
# 1                 NE             AL  PALMEIRA DOS INDIOS
# 2                 NE             AL  PALMEIRA DOS INDIOS
# 3                 NE             AL  PALMEIRA DOS INDIOS
# 4                 NE             AL  PALMEIRA DOS INDIOS
# ...              ...            ...                  ...
# 52538             SE             SP              BIRIGUI
# 52539             SE             MG                  UBA
# 52540             SE             MG                  UBA
# 52541             SE             SP              BIRIGUI
# 52542             SE             SP              BIRIGUI
#
#                                     Revenda      CNPJ da Revenda  \
# 0             SEVERINO S. LOPES & CIA. LTDA   05.331.412/0002-09
# 1             SEVERINO S. LOPES & CIA. LTDA   05.331.412/0002-09
# 2             SEVERINO S. LOPES & CIA. LTDA   05.331.412/0002-09
# ...

# %% [markdown]
# #### **Dezembro**

# %%
index = 'C:/Users/47131502023.1/Desktop/repositories/Projeto-4/Data/precos-gasolina-etanol-12.csv'
etanol12 = pd.read_csv(index, sep=';')
etanol12
# Out:
#       Regiao - Sigla Estado - Sigla    Municipio  \
# 0                 NE             MA   SANTA INES
# 1                 NE             MA   SANTA INES
# 2                 NE             MA   SANTA INES
# 3                  S             PR    ARAPONGAS
# 4                  S             PR    ARAPONGAS
# ...              ...            ...          ...
# 49448              S             PR  CAMPO LARGO
# 49449              S             PR  CAMPO LARGO
# 49450              S             RS       OSORIO
# 49451              S             RS       OSORIO
# 49452              S             RS       OSORIO
#
#                                            Revenda      CNPJ da Revenda  \
# 0                              POSTO MAGNOLIA LTDA   35.123.447/0001-32
# 1                              POSTO MAGNOLIA LTDA   35.123.447/0001-32
# 2                              POSTO MAGNOLIA LTDA   35.123.447/0001-32
# 3                           AUTO POSTO CATUAI LTDA   07.900.742/0004-65
# ...

# %% [markdown]
# ### **A análise deve responder às seguintes perguntas:**
#
# A análise deve responder às seguintes perguntas:
#
#     1. Como se comportaram o preço dos combustíveis durante os dois meses citados? Os valores do
#     etanol e da gasolina tiveram uma tendência de queda ou diminuição?
#     2. Qual o preço médio da gasolina e do etanol nesses dois meses?
#     3. Quais os 5 estados com o preço médio da gasolina e do etanol mais caros?
#     4. Qual o preço médio da gasolina e do etanol por estado?
#     5. Qual o município que possui o menor preço para a gasolina e para o etanol?
#     6. Qual o município que possui o maior preço para a gasolina e para o etanol?
#     7. Qual a região que possui o maior valor médio da gasolina?
#     8. Qual a região que possui o menor valor médio do etanol?
#     9. Há alguma correlação entre o valor do combustível (gasolina e etanol) e a região onde ele é vendido?
#     10.  Há alguma correlação entre o valor do combustível (gasolina e etanol) e a bandeira que vende ele?
#     Além disso, vocês deverão pensar em mais três perguntas que deverão ser respondidas por scripts.

# %% [markdown]
# ### **Tratamento de Dados**

# %% [markdown]
# #### **Juntando as duas tabelas**

# %%
etanol = pd.concat([etanol11,etanol12], ignore_index=True)
etanol
# Out:
#        Regiao - Sigla Estado - Sigla            Municipio  \
# 0                  NE             AL  PALMEIRA DOS INDIOS
# 1                  NE             AL  PALMEIRA DOS INDIOS
# 2                  NE             AL  PALMEIRA DOS INDIOS
# 3                  NE             AL  PALMEIRA DOS INDIOS
# 4                  NE             AL  PALMEIRA DOS INDIOS
# ...               ...            ...                  ...
# 101991              S             PR          CAMPO LARGO
# 101992              S             PR          CAMPO LARGO
# 101993              S             RS               OSORIO
# 101994              S             RS               OSORIO
# 101995              S             RS               OSORIO
#
#                                             Revenda      CNPJ da Revenda  \
# 0                     SEVERINO S. LOPES & CIA. LTDA   05.331.412/0002-09
# 1                     SEVERINO S. LOPES & CIA. LTDA   05.331.412/0002-09
# ...

# %% [markdown]
# #### **Retirando:**

# %% [markdown]
# - CEP;
# - CNPJ;
# - Valor de COmpra;
# - Unidade de Medida;
# - Complemento;
# - Numero Rua;
# - Nome da Rua;

# %%
etanol.drop(['Cep','CNPJ da Revenda','Valor de Compra','Unidade de Medida','Complemento','Numero Rua','Nome da Rua'], inplace=True, axis='columns')
etanol
# Out:
#        Regiao - Sigla Estado - Sigla            Municipio  \
# 0                  NE             AL  PALMEIRA DOS INDIOS
# 1                  NE             AL  PALMEIRA DOS INDIOS
# 2                  NE             AL  PALMEIRA DOS INDIOS
# 3                  NE             AL  PALMEIRA DOS INDIOS
# 4                  NE             AL  PALMEIRA DOS INDIOS
# ...               ...            ...                  ...
# 101991              S             PR          CAMPO LARGO
# 101992              S             PR          CAMPO LARGO
# 101993              S             RS               OSORIO
# 101994              S             RS               OSORIO
# 101995              S             RS               OSORIO
#
#                                             Revenda           Bairro  \
# 0                     SEVERINO S. LOPES & CIA. LTDA  JOSÉ MAIA COSTA
# 1                     SEVERINO S. LOPES & CIA. LTDA  JOSÉ MAIA COSTA
# ...

# %% [markdown]
# #### **Reordenando rotulos**

# %%
etanol = etanol.reindex(columns=['Regiao - Sigla','Estado - Sigla','Municipio','Bairro','Bandeira','Revenda','Valor de Venda','Produto','Data da Coleta'])
etanol
# Out:
#        Regiao - Sigla Estado - Sigla            Municipio           Bairro  \
# 0                  NE             AL  PALMEIRA DOS INDIOS  JOSÉ MAIA COSTA
# 1                  NE             AL  PALMEIRA DOS INDIOS  JOSÉ MAIA COSTA
# 2                  NE             AL  PALMEIRA DOS INDIOS  JOSÉ MAIA COSTA
# 3                  NE             AL  PALMEIRA DOS INDIOS       VILA MARIA
# 4                  NE             AL  PALMEIRA DOS INDIOS       VILA MARIA
# ...               ...            ...                  ...              ...
# 101991              S             PR          CAMPO LARGO           CENTRO
# 101992              S             PR          CAMPO LARGO           CENTRO
# 101993              S             RS               OSORIO           CENTRO
# 101994              S             RS               OSORIO           CENTRO
# 101995              S             RS               OSORIO           CENTRO
#
# ...
